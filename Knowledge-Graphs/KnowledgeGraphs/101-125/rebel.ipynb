# %%
# !pip install -q transformers
# !pip install -q networkx matplotlib
# !pip install -q pyvis
# !pip install -q neo4j

# %% [markdown]
# ## Downloading the COYO-reduced Kaggle dataset

# %%
# !pip install -q kaggle

# %%
# !kaggle datasets download -d anantjain1223/coyo-1k-reduced
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anantjain1223/coyo-1k-reduced
# License(s): MIT
# coyo-1k-reduced.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/coyo-1k-reduced.zip
# Out:
# Archive:  /content/coyo-1k-reduced.zip
# replace coyo-1k.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: coyo-1k.csv

# %%
import pandas as pd

df=pd.read_csv("/content/coyo-1k.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                                url   key  \
# 0           0  https://www.equipmentsalesandsurplus.com/v/vsp...  9113
# 1           1  https://texasfurniturehut.com/images/thumbs/00...  7371
# 2           2  https://cdn.shopify.com/s/files/1/1909/0703/pr...  1662
# 3           3  https://kelliesdesigns.net/wp-content/uploads/...  3390
# 4           4  https://cdn.houseplansservices.com/product/9ea...  3666
#
#         image_phash                                   original_caption  \
# 0  e5989a6799687992  Powermatic 60HH, 8" Jointer with Helical Cutte...
# 1  be179168cce0cc97           Picture of ELIJAH LEATHER POWER RECLINER
# 2  c04b03b43f1f3a67  8 x 10 Reprinted Old Photo of U.S. Mail, Tanan...
# 3  f9e3c64e0cd8b036               Police Officer In His Hands Snap Tab
# 4  84cfbfb0c8cab20e  House Design - Colonial Exterior - Front Eleva...
#
#                                                  tag  \
# 0       ['Jointer' 'Wood shaper' 'Thickness planer']
# 1             ['recliner' 'Power seat' 'Club chair']
# 2          ['Dog sled' 'Sled dog' 'Sled dog racing']
# 3  ['Police officer' 'Police commissioner' 'Handc...
# 4  ['farmhouse' 'manufactured home'\r\n 'North am...
#
#                                            attribute  \
# 0  ['repair which is a workbench or other surface...
# 1  ['recliner which has upholstered in fabric or ...
# 2  ['dog sled which has snow or ice'\r\n 'dog sle...
# 3  ['policeman which has badge' 'cop which has ba...
# 4  ['house which has exterior walls with siding, ...
#
#                                        short_caption  \
# 0   ['a table sawing machine on a white background']
# 1  ['a brown leather recliner chair on a white ba...
# 2  ['a black and white photo of a dog team pullin...
# 3  ['a pair of key chains with a police officer o...
# 4        ['this is a computer rendering of a house']
#
#                                     detailed_caption  \
# 0  ['a planer that is sitting on a table'\r\n 'a ...
# 1  ['a brown recliner sitting in front of a white...
# 2  ['a man riding a dog sled past a post office'\...
# 3  ["two key keychains with police officer's unif...
# 4  ['a two story brick house with a garage and po...
#
#                                          llm_caption
# 0  ['A table sawing machine on an all-white backg...
# 1  ['A Brown Leather Recliner Chair On A White Ba...
# 2  ['A black and white photo of a dog team pullin...
# 3  ["A pair of handmade key chains with a police ...
# 4  ['This is a computer rendered image of a house...

# %%
df=df[['url','short_caption']]
df.head()
# Out:
#                                                  url  \
# 0  https://www.equipmentsalesandsurplus.com/v/vsp...
# 1  https://texasfurniturehut.com/images/thumbs/00...
# 2  https://cdn.shopify.com/s/files/1/1909/0703/pr...
# 3  https://kelliesdesigns.net/wp-content/uploads/...
# 4  https://cdn.houseplansservices.com/product/9ea...
#
#                                        short_caption
# 0   ['a table sawing machine on a white background']
# 1  ['a brown leather recliner chair on a white ba...
# 2  ['a black and white photo of a dog team pullin...
# 3  ['a pair of key chains with a police officer o...
# 4        ['this is a computer rendering of a house']

# %% [markdown]
# ## Now that data loaded, Knowledge Graphs

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import math
from tqdm import tqdm
import torch
from pyvis.network import Network

# %% [markdown]
# ### Loading REBEL model for relational extraction

# %%
# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")
gen_kwargs = {
    "max_length": 256,
    "length_penalty": 0,
    "num_beams": 3,
    "num_return_sequences": 3,
}
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/344 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]

# %% [markdown]
# ## Relation extraction Triplets using REBEL-Large

# %%
def extract_triplets(text):
    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
    return triplets

# %% [markdown]
# ## Extraction of Triplets

# %%
# Text to extract triplets from
triplet_list=[]
url_list=[]

for i in tqdm(range(len(df))):
  text = df['short_caption'][i]
  url = df['url'][i]

  # Tokenizer text
  model_inputs = tokenizer(text, max_length=256, padding=True, truncation=True, return_tensors = 'pt')

  # Generate
  generated_tokens = model.generate(
      model_inputs["input_ids"].to(model.device),
      attention_mask=model_inputs["attention_mask"].to(model.device),
      **gen_kwargs,
  )

  # Extract text
  decoded_preds = tokenizer.batch_decode(generated_tokens, skip_special_tokens=False)

  # Extract triplets
  for _, sentence in enumerate(decoded_preds):
      triplet_list.append(extract_triplets(sentence))
      url_list.append(url)
# Out:
# 100%|██████████| 1000/1000 [36:02<00:00,  2.16s/it]

# %%
triplet_list
# Out:
# [[{'head': 'table sawing', 'type': 'subclass of', 'tail': 'machine'}],
#  [{'head': 'table sawing machine',
#    'type': 'subclass of',
#    'tail': 'white background'}],
#  [{'head': 'table sawing machine',
#    'type': 'has part',
#    'tail': 'white background'}],
#  [{'head': 'recliner', 'type': 'subclass of', 'tail': 'chair'}],
#  [{'head': 'leather', 'type': 'subclass of', 'tail': 'chair'}],
#  [{'head': 'chair', 'type': 'different from', 'tail': 'recliner'}],
#  [{'head': 'sled', 'type': 'subclass of', 'tail': 'dog team'}],
#  [{'head': 'sled', 'type': 'subclass of', 'tail': 'dog'}],
#  [{'head': 'sled', 'type': 'used by', 'tail': 'dog team'}],
#  [{'head': 'police officer', 'type': 'employer', 'tail': 'police'}],
#  [{'head': "'a pair of key chains with a police officer on them'",
#    'type': 'instance of',
#    'tail': 'key chain'}],
#  [{'head': 'police officer',
#    'type': 'field of this occupation',
#    'tail': 'police'}],
#  [{'head': 'computer rendering', 'type': 'part of', 'tail': 'computer'}],
#  [{'head': 'rendering', 'type': 'part of', 'tail': 'computer'}],
#  [{'head': 'computer rendering', 'type': 'depicts', 'tail': 'house'}],
#  [{'head': 'Grand Canyon', 'type': 'instance of', 'tail': 'canyon'}],
#  [{'head': 'canyon', 'type': 'has part', 'tail': 'grand canyon'}],
#  [{'head': 'Grand Canyon',
#    'type': 'located in the administrative territorial entity',
#    'tail': 'Utah'}],
#  [{'head': 'clock', 'type': 'part of', 'tail': 'tower'}],
#  [{'head': 'tower', 'type': 'has part', 'tail': 'clock'}],
#  [{'head': 'tower', 'type': 'has part', 'tail': 'clock'},
#   {'head': 'clock', 'type': 'part of', 'tail': 'tower'}],
#  [{'head': 'sandwich', 'type': 'part of', 'tail': 'plate'}],
#  [{'head': 'sandwich', 'type': 'has part', 'tail': 'plate'}],
#  [{'head': 'sandwich', 'type': 'uses', 'tail': 'plate'}],
#  [{'head': 'jude the obscure', 'type': 'lyrics by', 'tail': 'thomas hardy'}],
#  [{'head': 'jude the obscure', 'type': 'composer', 'tail': 'thomas hardy'}],
#  [{'head': 'jude the obscure', 'type': 'performer', 'tail': 'thomas hardy'}],
#  [{'head': 'wheat', 'type': 'instance of', 'tail': 'advertisement'}],
#  [{'head': 'wheat', 'type': 'subclass of', 'tail': 'advertisement'}],
#  [{'head': 'shredded wheat', 'type': 'instance of', 'tail': 'advertisement'}],
#  [{'head': 'gold necklace', 'type': 'depicts', 'tail': 'lion'}],
#  [{'head': 'necklace', 'type': 'depicts', 'tail': 'lion'}],
#  [{'head': 'gold', 'type': 'use', 'tail': 'necklace'}],
#  [{'head': 'cupcake', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'cupcakes', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'cupcakes', 'type': 'part of', 'tail': 'table'},
#   {'head': 'table', 'type': 'has part', 'tail': 'cupcakes'}],
#  [{'head': 'mountain bike', 'type': 'subclass of', 'tail': 'bike'}],
#  [{'head': 'mountain bike', 'type': 'instance of', 'tail': 'bike'}],
#  [{'head': 'mountain bike', 'type': 'depicts', 'tail': 'white background'}],
#  [{'head': 'cell phone', 'type': 'subclass of', 'tail': 'photo'}],
#  [{'head': 'cell phone', 'type': 'instance of', 'tail': 'photo'}],
#  [{'head': 'cell phone', 'type': 'use', 'tail': 'photo of a cell phone'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'white bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'diamond syrup', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'diamond syrup', 'type': 'has part', 'tail': 'red'}],
#  [{'head': 'red diamond syrup', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'Yellow Taxi', 'type': 'subclass of', 'tail': 'taxi'}],
#  [{'head': 'yellow taxi', 'type': 'part of', 'tail': 'street'}],
#  [{'head': 'Yellow Taxi',
#    'type': 'product or material produced',
#    'tail': 'yellow taxi'}],
#  [{'head': 'lighthouse', 'type': 'subclass of', 'tail': 'boat'}],
#  [{'head': 'lighthouse',
#    'type': 'different from',
#    'tail': 'boats are docked in the water next to a lighthouse'}],
#  [{'head': 'lighthouse',
#    'type': 'located in or next to body of water',
#    'tail': 'water'}],
#  [{'head': 'city', 'type': 'has part', 'tail': 'street'}],
#  [{'head': 'city', 'type': 'has parts of the class', 'tail': 'street'}],
#  [{'head': 'city', 'type': 'has part', 'tail': 'street'},
#   {'head': 'street', 'type': 'part of', 'tail': 'city'}],
#  [{'head': 'clock tower', 'type': 'part of', 'tail': 'building'}],
#  [{'head': 'clock tower', 'type': 'subclass of', 'tail': 'building'}],
#  [{'head': 'Clock tower', 'type': 'subclass of', 'tail': 'clock'}],
#  [{'head': 'George Orwell',
#    'type': 'notable work',
#    'tail': 'Nineteen Eighty-Four'},
#   {'head': 'Nineteen Eighty-Four', 'type': 'author', 'tail': 'Orwell'}],
#  [{'head': 'John F. Kennedy School of Government',
#    'type': 'part of',
#    'tail': 'Harvard University'}],
#  [{'head': 'George Orwell',
#    'type': 'notable work',
#    'tail': 'Nineteen Eighty-Four'},
#   {'head': 'Nineteen Eighty-Four', 'type': 'author', 'tail': 'George Orwell'}],
#  [{'head': 'building', 'type': 'subclass of', 'tail': 'photo'}],
#  [{'head': 'photo', 'type': 'depicts', 'tail': 'building'}],
#  [{'head': 'old black and white photo',
#    'type': 'depicts',
#    'tail': 'building'}],
#  [{'head': 'snow covered slope', 'type': 'facet of', 'tail': 'snowmobile'}],
#  [{'head': 'snow covered slope', 'type': 'subclass of', 'tail': 'snowmobile'}],
#  [{'head': 'snowmobile', 'type': 'uses', 'tail': 'snow covered slope'}],
#  [{'head': 'pool table', 'type': 'uses', 'tail': 'cue'}],
#  [{'head': 'cue', 'type': 'part of', 'tail': 'pool table'}],
#  [{'head': 'pool table', 'type': 'uses', 'tail': 'cue'},
#   {'head': 'cue', 'type': 'used by', 'tail': 'pool table'}],
#  [{'head': 'flower', 'type': 'has part', 'tail': 'leaf'}],
#  [{'head': 'flower', 'type': 'part of', 'tail': 'leaf'}],
#  [{'head': 'flower', 'type': 'part of', 'tail': 'leaf'},
#   {'head': 'leaf', 'type': 'has part', 'tail': 'flower'}],
#  [{'head': 'blackboard', 'type': 'subclass of', 'tail': 'table'}],
#  [{'head': 'table', 'type': 'has part', 'tail': 'blackboard'}],
#  [{'head': 'blackboard', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'voice - activated systems',
#    'type': 'instance of',
#    'tail': 'bar chart'}],
#  [{'head': 'voice - activated systems',
#    'type': 'subclass of',
#    'tail': 'bar chart'}],
#  [{'head': 'voice - activated systems',
#    'type': 'subclass of',
#    'tail': 'systems'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillows', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillow', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'drawer', 'type': 'part of', 'tail': 'kitchen cabinet'}],
#  [{'head': 'kitchen cabinet', 'type': 'has part', 'tail': 'drawer'}],
#  [{'head': 'kitchen cabinet', 'type': 'has part', 'tail': 'drawer'},
#   {'head': 'drawer', 'type': 'part of', 'tail': 'kitchen cabinet'}],
#  [{'head': 'buildings', 'type': 'part of', 'tail': 'campus'}],
#  [{'head': 'campus', 'type': 'has parts of the class', 'tail': 'buildings'}],
#  [{'head': 'campus', 'type': 'has part', 'tail': 'buildings'}],
#  [{'head': "'a screenshot of a woman with red hair'",
#    'type': 'instance of',
#    'tail': 'screenshot'}],
#  [{'head': 'screenshot of a woman with red hair',
#    'type': 'instance of',
#    'tail': 'screenshot'}],
#  [{'head': 'screenshot of a woman with red hair',
#    'type': 'depicts',
#    'tail': 'red hair'}],
#  [{'head': 'water heater', 'type': 'has part', 'tail': 'hose'}],
#  [{'head': 'hose', 'type': 'part of', 'tail': 'water heater'}],
#  [{'head': 'water heater', 'type': 'has part', 'tail': 'hose attached to it'}],
#  [{'head': 'flower', 'type': 'part of', 'tail': 'pot'}],
#  [{'head': "'a lot of pumpkins and flowers in pots'",
#    'type': 'main subject',
#    'tail': 'pumpkins'}],
#  [{'head': 'flower', 'type': 'part of', 'tail': 'pots'}],
#  [{'head': 'flowers', 'type': 'used by', 'tail': 'candles'}],
#  [{'head': 'flowers', 'type': 'used by', 'tail': 'candles'},
#   {'head': 'candles', 'type': 'uses', 'tail': 'flowers'}],
#  [{'head': 'table', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'skirt', 'type': 'has part', 'tail': 'top'}],
#  [{'head': 'skirt', 'type': 'subclass of', 'tail': 'top'}],
#  [{'head': 'skirt', 'type': 'different from', 'tail': 'top'},
#   {'head': 'top', 'type': 'different from', 'tail': 'skirt'}],
#  [{'head': 'desk', 'type': 'subclass of', 'tail': 'chair'}],
#  [{'head': 'chair', 'type': 'subclass of', 'tail': 'desk'}],
#  [{'head': 'chair', 'type': 'different from', 'tail': 'desk'}],
#  [{'head': 'champion logo', 'type': 'depicts', 'tail': 'blue'}],
#  [{'head': 'champion logo', 'type': 'has part', 'tail': 'blue'}],
#  [{'head': 'logo on a blue background',
#    'type': 'subclass of',
#    'tail': 'logo'}],
#  [{'head': "'a woman with blonde and pink hair posing for a picture'",
#    'type': 'instance of',
#    'tail': 'picture'}],
#  [{'head': 'Pink hair', 'type': 'has part', 'tail': 'blonde'}],
#  [{'head': "'a woman with blonde and pink hair posing for a picture",
#    'type': 'instance of',
#    'tail': 'picture'}],
#  [{'head': 'muffin', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'muffin', 'type': 'subclass of', 'tail': 'table'}],
#  [{'head': 'muffin', 'type': 'part of', 'tail': 'wooden table'}],
#  [{'head': 'drawer', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'table', 'type': 'has part', 'tail': 'drawer'}],
#  [{'head': 'table', 'type': 'has part', 'tail': 'drawer'},
#   {'head': 'drawer', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'}],
#  [{'head': 'tie', 'type': 'part of', 'tail': 'suit'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'},
#   {'head': 'tie', 'type': 'part of', 'tail': 'suit'}],
#  [{'head': 'quilt', 'type': 'used by', 'tail': 'women'}],
#  [{'head': 'quilt', 'type': 'owned by', 'tail': 'women'}],
#  [{'head': 'quilt', 'type': 'used by', 'tail': 'quilters'}],
#  [{'head': 'man', 'type': 'spouse', 'tail': 'woman'}],
#  [{'head': 'man', 'type': 'spouse', 'tail': 'woman'},
#   {'head': 'woman', 'type': 'spouse', 'tail': 'man'}],
#  [{'head': 'man', 'type': 'opposite of', 'tail': 'woman'}],
#  [{'head': 'butterfly applique', 'type': 'part of', 'tail': 'dress'}],
#  [{'head': 'applique', 'type': 'part of', 'tail': 'dress'}],
#  [{'head': 'butterfly applique', 'type': 'use', 'tail': 'dress'}],
#  [{'head': "'a woman standing in front of a white background'",
#    'type': 'depicts',
#    'tail': 'white background'}],
#  [{'head': "'a woman standing in front of a white background'",
#    'type': 'depicts',
#    'tail': 'white'}],
#  [{'head': 'White background', 'type': 'subclass of', 'tail': 'background'}],
#  [{'head': 'desk', 'type': 'different from', 'tail': 'chair'},
#   {'head': 'chair', 'type': 'different from', 'tail': 'desk'}],
#  [{'head': 'desk', 'type': 'different from', 'tail': 'chair'}],
#  [{'head': 'chair', 'type': 'different from', 'tail': 'desk'}],
#  [{'head': 'sectional', 'type': 'subclass of', 'tail': 'sofa'}],
#  [{'head': 'sectional sofa', 'type': 'has part', 'tail': 'recliners'}],
#  [{'head': 'sectional sofa', 'type': 'has part', 'tail': 'recliner'}],
#  [{'head': 'Keep Calm and never give up',
#    'type': 'instance of',
#    'tail': 'sign'}],
#  [{'head': 'Never Give Up', 'type': 'instance of', 'tail': 'sign'}],
#  [{'head': 'Never give up', 'type': 'facet of', 'tail': 'keep calm'}],
#  [{'head': 'skull', 'type': 'part of', 'tail': 'black jacket'}],
#  [{'head': 'black jacket', 'type': 'depicts', 'tail': 'skull'}],
#  [{'head': 'skull', 'type': 'subclass of', 'tail': 'black'}],
#  [{'head': 'temperature', 'type': 'facet of', 'tail': 'temperature'}],
#  [{'head': 'temperature', 'type': 'different from', 'tail': 'temperature'}],
#  [{'head': 'temperature', 'type': 'subclass of', 'tail': 'temperature'}],
#  [{'head': "'a christmas market in the middle of a town'",
#    'type': 'instance of',
#    'tail': 'christmas market'}],
#  [{'head': 'market', 'type': 'facet of', 'tail': 'christmas'}],
#  [{'head': 'market', 'type': 'part of', 'tail': 'town'}],
#  [{'head': 'chips', 'type': 'part of', 'tail': 'sandwich'}],
#  [{'head': 'sandwich', 'type': 'has part', 'tail': 'chips'}],
#  [{'head': 'chips', 'type': 'subclass of', 'tail': 'sandwich'}],
#  [{'head': 'salariess', 'type': 'subclass of', 'tail': 'wage'}],
#  [{'head': 'wage', 'type': 'different from', 'tail': 'salariess'},
#   {'head': 'salariess', 'type': 'different from', 'tail': 'wage'}],
#  [{'head': 'wage', 'type': 'different from', 'tail': 'salariess'}],
#  [{'head': 'dock', 'type': 'subclass of', 'tail': 'body of water'}],
#  [{'head': 'dock', 'type': 'part of', 'tail': 'body of water'}],
#  [{'head': 'dock', 'type': 'subclass of', 'tail': 'water'}],
#  [{'head': 'pink', 'type': 'subclass of', 'tail': 'handbag'}],
#  [{'head': 'pink', 'type': 'subclass of', 'tail': 'white'}],
#  [{'head': 'pink', 'type': 'opposite of', 'tail': 'white'}],
#  [{'head': "'a close up of a bracelet with a heart on it'",
#    'type': 'depicts',
#    'tail': 'bracelet'}],
#  [{'head': "'a close up of a bracelet with a heart on it'",
#    'type': 'instance of',
#    'tail': 'bracelet'}],
#  [{'head': "'a close up", 'type': 'depicts', 'tail': 'bracelet'}],
#  [{'head': "'a little girl standing with her hands on her hips'",
#    'type': 'depicts',
#    'tail': 'little girl standing with her hands on her hips'}],
#  [{'head': "'a little girl standing with her hands on her hips'",
#    'type': 'depicts',
#    'tail': 'little girl'}],
#  [{'head': "'a little girl standing with her hands on her hips'",
#    'type': 'main subject',
#    'tail': 'little girl standing with her hands on her hips'}],
#  [{'head': 'furniture', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'window', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'living room',
#    'type': 'has parts of the class',
#    'tail': 'furniture'}],
#  [{'head': 'signing autographs', 'type': 'facet of', 'tail': 'autograph'}],
#  [{'head': 'autograph', 'type': 'subclass of', 'tail': 'signing'}],
#  [{'head': 'signing autographs',
#    'type': 'product or material produced',
#    'tail': 'autograph'}],
#  [{'head': 'ruby', 'type': 'subclass of', 'tail': 'diamond'}],
#  [{'head': 'diamond ring', 'type': 'has part', 'tail': 'ruby'}],
#  [{'head': 'antique ruby and diamond ring',
#    'type': 'subclass of',
#    'tail': 'ring'}],
#  [{'head': 'microphone', 'type': 'part of', 'tail': 'podium'}],
#  [{'head': 'podium', 'type': 'has part', 'tail': 'microphone'}],
#  [{'head': 'microphone', 'type': 'different from', 'tail': 'podium'}],
#  [{'head': 'trumpet', 'type': 'applies to jurisdiction', 'tail': 'uniform'}],
#  [{'head': "'a black and white photo of a man in uniform playing a trumpet'",
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': 'trumpet', 'type': 'subclass of', 'tail': 'black and white'}],
#  [{'head': 'lens', 'type': 'part of', 'tail': 'camera'}],
#  [{'head': 'camera', 'type': 'has part', 'tail': 'lens'}],
#  [{'head': 'camera', 'type': 'has part', 'tail': 'lens'},
#   {'head': 'lens', 'type': 'part of', 'tail': 'camera'}],
#  [{'head': 'mannequin mannequin mannequin mannequin mannequin mannequin mannequin mann',
#    'type': 'depicts',
#    'tail': 'mannequin mannequin mannequin mannequin mannequin mann'}],
#  [{'head': 'mannequin mannequin mannequin mannequin mannequin mannequin mannequin mann',
#    'type': 'depicts',
#    'tail': 'mannequin mannequin mannequin mannequin mannequin mannequin mann'}],
#  [{'head': 'mannequin mannequin mannequin mannequin mannequin mannequin mannequin mannequin mann',
#    'type': 'depicts',
#    'tail': 'mannequin mannequin mannequin mannequin mannequin mannequin mann'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'}],
#  [{'head': 'tie', 'type': 'subclass of', 'tail': 'suit'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'},
#   {'head': 'tie', 'type': 'part of', 'tail': 'suit'}],
#  [{'head': 'sprayer', 'type': 'part of', 'tail': 'tractor'}],
#  [{'head': 'sprayer', 'type': 'subclass of', 'tail': 'tractor'}],
#  [{'head': 'tractor', 'type': 'has part', 'tail': 'sprayer'}],
#  [{'head': 'cabinets', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'appliances', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'cabinets', 'type': 'part of', 'tail': 'kitchen'},
#   {'head': 'appliances', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'signs', 'type': 'part of', 'tail': 'street'}],
#  [{'head': 'signs', 'type': 'subclass of', 'tail': 'walking'}],
#  [{'head': 'signs', 'type': 'part of', 'tail': 'walking'}],
#  [{'head': 'chain strap', 'type': 'part of', 'tail': 'purse'}],
#  [{'head': 'purse', 'type': 'has part', 'tail': 'chain strap'}],
#  [{'head': 'chain', 'type': 'part of', 'tail': 'purse'}],
#  [{'head': 'hose', 'type': 'has part', 'tail': 'fitting'}],
#  [{'head': 'hose', 'type': 'has part', 'tail': 'fitting'},
#   {'head': 'fitting', 'type': 'part of', 'tail': 'hose'}],
#  [{'head': 'blue', 'type': 'opposite of', 'tail': 'white'}],
#  [{'head': 'courtroom', 'type': 'subclass of', 'tail': 'group of people'}],
#  [{'head': 'courtroom', 'type': 'subclass of', 'tail': 'group'}],
#  [{'head': 'courtroom',
#    'type': 'subclass of',
#    'tail': 'group of people standing next to each other'}],
#  [{'head': "'a painting of a woman in a colorful dress'",
#    'type': 'instance of',
#    'tail': 'painting'}],
#  [{'head': 'painting of a woman in a colorful dress',
#    'type': 'depicts',
#    'tail': 'colorful dress'}],
#  [{'head': 'painting of a woman in a colorful dress',
#    'type': 'instance of',
#    'tail': 'painting'}],
#  [{'head': "'a close up of a car with flames on it'",
#    'type': 'depicts',
#    'tail': 'car'}],
#  [{'head': 'car', 'type': 'has part', 'tail': 'flames'}],
#  [{'head': "'a close up of a car with flames on it'",
#    'type': 'depicts',
#    'tail': 'car with flames on it'}],
#  [{'head': "'a woman and a child smiling for a picture'",
#    'type': 'instance of',
#    'tail': 'picture'}],
#  [{'head': "'a woman and a child smiling for a picture'",
#    'type': 'depicts',
#    'tail': 'picture'}],
#  [{'head': "'a woman and a child smiling for a picture'",
#    'type': 'genre',
#    'tail': 'picture'}],
#  [{'head': "'a painting of three white orchids with green leaves'",
#    'type': 'depicts',
#    'tail': 'orchid'}],
#  [{'head': 'painting of three white orchids with green leaves',
#    'type': 'depicts',
#    'tail': 'orchid'}],
#  [{'head': "'a painting of three white orchid with green leaves'",
#    'type': 'depicts',
#    'tail': 'orchid'}],
#  [{'head': 'Yellow raft', 'type': 'subclass of', 'tail': 'raft'}],
#  [{'head': 'Yellow raft', 'type': 'instance of', 'tail': 'raft'}],
#  [{'head': 'raft', 'type': 'part of', 'tail': 'body of water'}],
#  [{'head': 'Blue glove', 'type': 'subclass of', 'tail': 'glove'}],
#  [{'head': "'a person in blue gloves",
#    'type': 'depicts',
#    'tail': 'reaching for something in a box'}],
#  [{'head': "'a person in blue gloves is reaching for something in a box'",
#    'type': 'main subject',
#    'tail': 'blue gloves'}],
#  [{'head': 'countertops', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'counter tops', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'cabinets', 'type': 'has part', 'tail': 'countertops'}],
#  [{'head': 'power filter', 'type': 'part of', 'tail': 'aquarium'}],
#  [{'head': 'power filterr', 'type': 'use', 'tail': 'aquarium'}],
#  [{'head': 'aquarium', 'type': 'has part', 'tail': 'power filterr'}],
#  [{'head': 'projector screen', 'type': 'part of', 'tail': 'classroom'}],
#  [{'head': 'red chair', 'type': 'part of', 'tail': 'classroom'}],
#  [{'head': 'projector', 'type': 'part of', 'tail': 'classroom'}],
#  [{'head': "'a woman in a wedding dress standing in front of a wall'",
#    'type': 'depicts',
#    'tail': 'wedding dress'}],
#  [{'head': 'wedding dress', 'type': 'facet of', 'tail': 'wedding'}],
#  [{'head': 'wedding', 'type': 'uses', 'tail': 'dress'}],
#  [{'head': 'snow covered ground', 'type': 'has part', 'tail': 'snow'}],
#  [{'head': 'snow covered ground', 'type': 'subclass of', 'tail': 'snow'}],
#  [{'head': 'snow covered ground', 'type': 'facet of', 'tail': 'snow'}],
#  [{'head': 'bridge', 'type': 'crosses', 'tail': 'train track'}],
#  [{'head': 'train track', 'type': 'connects with', 'tail': 'bridge'},
#   {'head': 'bridge', 'type': 'connects with', 'tail': 'train track'}],
#  [{'head': 'under a bridge', 'type': 'crosses', 'tail': 'train track'}],
#  [{'head': 'dress', 'type': 'subclass of', 'tail': 'photo'}],
#  [{'head': 'dress', 'type': 'instance of', 'tail': 'photo'}],
#  [{'head': 'dress', 'type': 'subclass of', 'tail': 'black and white'}],
#  [{'head': '2019', 'type': 'point in time', 'tail': '2019'}],
#  [{'head': '2019 subaruna', 'type': 'point in time', 'tail': '2019'}],
#  [{'head': "'a black 2019 subaruna", 'type': 'point in time', 'tail': '2019'}],
#  [{'head': 'helmet', 'type': 'has part', 'tail': 'logo'}],
#  [{'head': 'helmet', 'type': 'has part', 'tail': 'logo'},
#   {'head': 'logo', 'type': 'part of', 'tail': 'helmet'}],
#  [{'head': 'helmet', 'type': 'manufacturer', 'tail': 'pittsburgh steelers'}],
#  [{'head': 'painting of a man holding a bird and flowers',
#    'type': 'depicts',
#    'tail': 'bird'}],
#  [{'head': "'a painting of a man holding a bird and flowers'",
#    'type': 'instance of',
#    'tail': 'painting'}],
#  [{'head': 'painting', 'type': 'depicts', 'tail': 'bird'}],
#  [{'head': 'skull', 'type': 'part of', 'tail': 'skull'}],
#  [{'head': 'skull', 'type': 'part of', 'tail': 'blue blanket'}],
#  [{'head': 'skull', 'type': 'subclass of', 'tail': 'knitted'}],
#  [{'head': 'drinks', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'glasses', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'glass', 'type': 'use', 'tail': 'drink'}],
#  [{'head': 'website design', 'type': 'part of', 'tail': 'website'}],
#  [{'head': "'a red and white restaurant website design'",
#    'type': 'instance of',
#    'tail': 'website design'}],
#  [{'head': 'website design', 'type': 'facet of', 'tail': 'website'}],
#  [{'head': 'old black and white photo', 'type': 'depicts', 'tail': 'town'}],
#  [{'head': 'photo', 'type': 'depicts', 'tail': 'town'}],
#  [{'head': 'old black and white photo',
#    'type': 'subclass of',
#    'tail': 'photo'}],
#  [{'head': 'ceiling fan', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'bed room', 'type': 'has part', 'tail': 'bed'}],
#  [{'head': 'table', 'type': 'opposite of', 'tail': 'floor'}],
#  [{'head': 'table', 'type': 'different from', 'tail': 'floor'},
#   {'head': 'floor', 'type': 'different from', 'tail': 'table'}],
#  [{'head': 'table', 'type': 'different from', 'tail': 'floor'}],
#  [{'head': 'car', 'type': 'has part', 'tail': 'interior'}],
#  [{'head': 'interior', 'type': 'part of', 'tail': 'car'}],
#  [{'head': 'interior', 'type': 'part of', 'tail': 'car'},
#   {'head': 'car', 'type': 'has part', 'tail': 'interior'}],
#  [{'head': 'oven', 'type': 'subclass of', 'tail': 'stove top'}],
#  [{'head': 'oven', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'stove top oven', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'John F. Kennedy School of Government',
#    'type': 'part of',
#    'tail': 'Harvard University'}],
#  [{'head': 'Docked in the water', 'type': 'instance of', 'tail': 'boat'}],
#  [{'head': 'Docked in the water', 'type': 'instance of', 'tail': 'boats'}],
#  [{'head': 'passport', 'type': 'used by', 'tail': 'person'}],
#  [{'head': 'passport', 'type': 'owned by', 'tail': 'person'}],
#  [{'head': 'passport', 'type': 'subclass of', 'tail': 'person'}],
#  [{'head': 'table', 'type': 'part of', 'tail': 'dinning room'}],
#  [{'head': 'table', 'type': 'use', 'tail': 'dinning room'}],
#  [{'head': 'table and chairs', 'type': 'part of', 'tail': 'dinning room'}],
#  [{'head': 'toilet', 'type': 'part of', 'tail': 'bathroom'}],
#  [{'head': 'shower', 'type': 'part of', 'tail': 'bathroom'}],
#  [{'head': 'toilet', 'type': 'part of', 'tail': 'bathroom'},
#   {'head': 'sink', 'type': 'part of', 'tail': 'bathroom'}],
#  [{'head': 'green', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'white', 'type': 'has part', 'tail': 'green'}],
#  [{'head': 'green hat', 'type': 'has part', 'tail': 'white background'}],
#  [{'head': 'ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny',
#    'type': 'shares border with',
#    'tail': 'ny ny ny ny ny ny ny ny ny ny ny ny'}],
#  [{'head': 'ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny',
#    'type': 'shares border with',
#    'tail': 'ny ny ny ny ny ny ny ny ny ny ny ny ny ny'}],
#  [{'head': 'ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny ny',
#    'type': 'shares border with',
#    'tail': 'ny ny ny ny ny ny ny ny ny ny ny ny ny ny'}],
#  [{'head': 'stage', 'type': 'subclass of', 'tail': 'group'}],
#  [{'head': 'stage', 'type': 'part of', 'tail': 'group'}],
#  [{'head': 'stage', 'type': 'subclass of', 'tail': 'group of people'}],
#  [{'head': 'fire place', 'type': 'subclass of', 'tail': 'patio'}],
#  [{'head': 'fire place', 'type': 'part of', 'tail': 'patio'}],
#  [{'head': 'fire place', 'type': 'use', 'tail': 'patio'}],
#  [{'head': 'white pants', 'type': 'subclass of', 'tail': 'dress'}],
#  [{'head': 'pink dress', 'type': 'followed by', 'tail': 'white pants'}],
#  [{'head': 'dress', 'type': 'has part', 'tail': 'pants'}],
#  [{'head': 'wine', 'type': 'has part', 'tail': 'bottle'}],
#  [{'head': 'wine', 'type': 'uses', 'tail': 'bottle'}],
#  [{'head': 'wine', 'type': 'subclass of', 'tail': 'bottle'}],
#  [{'head': "'a view of a village in the mountains'",
#    'type': 'depicts',
#    'tail': 'mountain'}],
#  [{'head': "'a view of a village in the mountains'",
#    'type': 'depicts',
#    'tail': 'village'}],
#  [{'head': "'a view of a village in the mountains'",
#    'type': 'depicts',
#    'tail': 'village in the mountains'}],
#  [{'head': "'a couple of fake cows standing next to each other'",
#    'type': 'depicts',
#    'tail': 'fake cows'}],
#  [{'head': "'a couple of fake cows standing next to each other'",
#    'type': 'depicts',
#    'tail': 'fake cow'}],
#  [{'head': "'a couple of fake cows standing next to each other'",
#    'type': 'main subject',
#    'tail': 'fake cows'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'},
#   {'head': 'bedroom', 'type': 'has part', 'tail': 'bed'}],
#  [{'head': 'window', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'christmas lights', 'type': 'subclass of', 'tail': 'decorations'}],
#  [{'head': 'christmas lights and decorations',
#    'type': 'subclass of',
#    'tail': 'decor'}],
#  [{'head': 'christmas lights and decorations',
#    'type': 'part of',
#    'tail': 'hallway'}],
#  [{'head': 'wooden model', 'type': 'depicts', 'tail': 'boat'}],
#  [{'head': 'boat', 'type': 'subclass of', 'tail': 'wooden'}],
#  [{'head': 'model', 'type': 'depicts', 'tail': 'boat'}],
#  [{'head': 'construction worker',
#    'type': 'field of this occupation',
#    'tail': 'building under construction'},
#   {'head': 'building under construction',
#    'type': 'practiced by',
#    'tail': 'construction worker'}],
#  [{'head': 'building under construction',
#    'type': 'practiced by',
#    'tail': 'construction worker'}],
#  [{'head': 'building', 'type': 'studied by', 'tail': 'construction'}],
#  [{'head': 'bra', 'type': 'subclass of', 'tail': 'panties'}],
#  [{'head': 'bra', 'type': 'part of', 'tail': 'panties'}],
#  [{'head': 'bra', 'type': 'different from', 'tail': 'panties'}],
#  [{'head': 'furniture', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'fire place', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'living room',
#    'type': 'has parts of the class',
#    'tail': 'furniture'}],
#  [{'head': "'days inn by wyndham'",
#    'type': 'narrative location',
#    'tail': 'wyndham'}],
#  [{'head': "'days inn by wyndham'", 'type': 'named after', 'tail': 'wyndham'}],
#  [{'head': "'days inn by wyndham'",
#    'type': 'based on',
#    'tail': 'days inn by wyndham'}],
#  [{'head': 'surfboard', 'type': 'uses', 'tail': 'wave'}],
#  [{'head': 'surfboard', 'type': 'uses', 'tail': 'wave'},
#   {'head': 'wave', 'type': 'used by', 'tail': 'surfboard'}],
#  [{'head': 'surfing', 'type': 'uses', 'tail': 'surfboard'}],
#  [{'head': 'drums', 'type': 'subclass of', 'tail': 'people'}],
#  [{'head': 'drums', 'type': 'instance of', 'tail': 'group of people'}],
#  [{'head': 'drums', 'type': 'subclass of', 'tail': 'group of people'}],
#  [{'head': 'skyscraper', 'type': 'subclass of', 'tail': 'building'}],
#  [{'head': 'street', 'type': 'has part', 'tail': 'building'}],
#  [{'head': 'street', 'type': 'has part', 'tail': 'buildings'}],
#  [{'head': 'furniture', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'tv', 'type': 'uses', 'tail': 'flat screen'}],
#  [{'head': 'flat screen tv', 'type': 'subclass of', 'tail': 'living room'}],
#  [{'head': 'table', 'type': 'subclass of', 'tail': 'machine'}],
#  [{'head': 'table', 'type': 'part of', 'tail': 'machine'}],
#  [{'head': 'machine', 'type': 'uses', 'tail': 'table'}],
#  [{'head': 'table', 'type': 'has part', 'tail': 'window'}],
#  [{'head': 'table', 'type': 'opposite of', 'tail': 'window'}],
#  [{'head': 'window', 'type': 'opposite of', 'tail': 'table'}],
#  [{'head': 'dock', 'type': 'subclass of', 'tail': 'catamaran'}],
#  [{'head': 'dock', 'type': 'part of', 'tail': 'catamaran'}],
#  [{'head': 'dock', 'type': 'item operated', 'tail': 'catamaran'}],
#  [{'head': 'staircase', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'furniture', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'living room',
#    'type': 'has parts of the class',
#    'tail': 'furniture'}],
#  [{'head': "'a bottle of courvoisir xo'",
#    'type': 'instance of',
#    'tail': 'courvoisir'}],
#  [{'head': "'a bottle of courvoisir xo'",
#    'type': 'has part',
#    'tail': 'courvoisir'}],
#  [{'head': "'a bottle of courvoisir xo'",
#    'type': 'named after',
#    'tail': 'courvoisir'}],
#  [{'head': 'group', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'group of people standing in a room',
#    'type': 'subclass of',
#    'tail': 'room'}],
#  [{'head': 'group of people standing in a room',
#    'type': 'part of',
#    'tail': 'group of people standing in a room'}],
#  [{'head': 'oven', 'type': 'subclass of', 'tail': 'stove top'}],
#  [{'head': 'stove top oven', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'oven', 'type': 'part of', 'tail': 'kitchen'}],
#  [{'head': 'champagne', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'Champagne', 'type': 'subclass of', 'tail': 'champagne'}],
#  [{'head': "'a bottle of champagne sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'champagne'}],
#  [{'head': 'microphone', 'type': 'used by', 'tail': 'woman'}],
#  [{'head': "'a woman standing in front of a microphone'",
#    'type': 'uses',
#    'tail': 'microphone'}],
#  [{'head': 'microphone',
#    'type': 'part of',
#    'tail': 'standing in front of a microphone'}],
#  [{'head': "'a bunch of balloons sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'balloons'}],
#  [{'head': "'a bunch of balloons sitting on top of a table'",
#    'type': 'depicts',
#    'tail': 'balloons'}],
#  [{'head': "'a bunch of balloons sitting on top of a table'",
#    'type': 'main subject',
#    'tail': 'balloons'}],
#  [{'head': 'typewriter', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'typewriter', 'type': 'uses', 'tail': 'table'}],
#  [{'head': 'typewriter', 'type': 'location', 'tail': 'table'}],
#  [{'head': 'zipper', 'type': 'part of', 'tail': 'sweater'}],
#  [{'head': 'zipper', 'type': 'part of', 'tail': 'zipper'}],
#  [{'head': 'sweater', 'type': 'has part', 'tail': 'chest'}],
#  [{'head': 'window', 'type': 'part of', 'tail': 'building'}],
#  [{'head': 'windows', 'type': 'part of', 'tail': 'building'}],
#  [{'head': 'window', 'type': 'part of', 'tail': 'building'},
#   {'head': 'building', 'type': 'has part', 'tail': 'window'}],
#  [{'head': 'speech', 'type': 'uses', 'tail': 'podium'}],
#  [{'head': 'podium', 'type': 'use', 'tail': 'speech'}],
#  [{'head': 'speech', 'type': 'location', 'tail': 'podium'}],
#  [{'head': 'car charger', 'type': 'has part', 'tail': 'cable'}],
#  [{'head': 'cable', 'type': 'part of', 'tail': 'car charger'}],
#  [{'head': 'cable', 'type': 'connects with', 'tail': 'car charger'}],
#  [{'head': 'couch', 'type': 'opposite of', 'tail': 'floor'}],
#  [{'head': 'couch', 'type': 'different from', 'tail': 'floor'}],
#  [{'head': 'couch', 'type': 'different from', 'tail': 'floor'},
#   {'head': 'floor', 'type': 'different from', 'tail': 'couch'}],
#  [{'head': 'figure', 'type': 'part of', 'tail': 'pokemon'}],
#  [{'head': 'figure on a white background',
#    'type': 'depicts',
#    'tail': 'pokemon'}],
#  [{'head': "'a close up of a pokemon figure on a white background",
#    'type': 'depicts',
#    'tail': 'pokemon figure'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'bed room', 'type': 'has part', 'tail': 'bed'}],
#  [{'head': 'flat screen tv', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'walls', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'white walls', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'white walls', 'type': 'subclass of', 'tail': 'room'}],
#  [{'head': 'remote control', 'type': 'part of', 'tail': 'remote'}],
#  [{'head': 'remote controls', 'type': 'has part', 'tail': 'remote'}],
#  [{'head': 'remote controls', 'type': 'has part', 'tail': 'remote control'}],
#  [{'head': 'pen tip', 'type': 'part of', 'tail': 'pen'}],
#  [{'head': 'pen', 'type': 'has part', 'tail': 'pen tip'},
#   {'head': 'pen tip', 'type': 'part of', 'tail': 'pen'}],
#  [{'head': 'pen', 'type': 'has part', 'tail': 'pen tip'}],
#  [{'head': 'diamond', 'type': 'use', 'tail': 'ring'}],
#  [{'head': 'ring', 'type': 'has part', 'tail': 'diamond'}],
#  [{'head': 'diamond', 'type': 'use', 'tail': 'ring'},
#   {'head': 'ring', 'type': 'uses', 'tail': 'diamond'}],
#  [{'head': 'office chair', 'type': 'part of', 'tail': 'floor'}],
#  [{'head': 'chair', 'type': 'subclass of', 'tail': 'office chair'}],
#  [{'head': 'office chair', 'type': 'part of', 'tail': 'floor'},
#   {'head': 'floor', 'type': 'has part', 'tail': 'office chair'}],
#  [{'head': 'pendant', 'type': 'part of', 'tail': 'chain'}],
#  [{'head': 'pendant', 'type': 'part of', 'tail': 'chain'},
#   {'head': 'chain', 'type': 'has part', 'tail': 'pendant'}],
#  [{'head': 'glass', 'type': 'subclass of', 'tail': 'pendant'}],
#  [{'head': 'ring', 'type': 'has part', 'tail': 'stone'}],
#  [{'head': 'ring', 'type': 'has part', 'tail': 'stone'},
#   {'head': 'stone', 'type': 'part of', 'tail': 'ring'}],
#  [{'head': 'silver ring', 'type': 'has part', 'tail': 'stone'}],
#  [{'head': "'a bunch of rings sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'rings'}],
#  [{'head': "'a bunch of rings sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'ring'}],
#  [{'head': "'a bunch of rings sitting on top of a table'",
#    'type': 'depicts',
#    'tail': 'ring'}],
#  [{'head': "'the sun is setting over a body of water'",
#    'type': 'main subject',
#    'tail': 'sun is setting over a body of water'}],
#  [{'head': "'the sun is setting over a body of water'",
#    'type': 'depicts',
#    'tail': 'sun'}],
#  [{'head': 'the sun is setting over a body of water',
#    'type': 'depicts',
#    'tail': 'body of water'}],
#  [{'head': 'motorcycle', 'type': 'has part', 'tail': 'silver'}],
#  [{'head': 'motorcycle', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'motorcycle', 'type': 'different from', 'tail': 'motorcycle'}],
#  [{'head': "'a man holding a dog in front of a cabin'",
#    'type': 'depicts',
#    'tail': 'dog'}],
#  [{'head': "'a man holding a dog in front of a cabin'",
#    'type': 'depicts',
#    'tail': "'a man holding a dog in front of a cabin'"}],
#  [{'head': "'a man holding a dog in front of a cabin'",
#    'type': 'depicts',
#    'tail': 'a dog'}],
#  [{'head': "'a woman wearing a black and white dress'",
#    'type': 'depicts',
#    'tail': 'dress'}],
#  [{'head': "'a woman wearing a black and white dress'",
#    'type': 'instance of',
#    'tail': 'dress'}],
#  [{'head': 'dress', 'type': 'depicts', 'tail': 'woman'}],
#  [{'head': 'a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture',
#    'type': 'followed by',
#    'tail': 'a picture of a picture of a picture of a picture of a picture of a picture'}],
#  [{'head': 'a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture',
#    'type': 'depicts',
#    'tail': 'a picture of a picture of a picture of a picture of a picture of a picture'}],
#  [{'head': 'a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture of a picture',
#    'type': 'followed by',
#    'tail': 'a picture of a picture of a picture of a picture of a picture of a picture'}],
#  [{'head': 'John Milton', 'type': 'notable work', 'tail': 'Paradise Lost'},
#   {'head': 'Paradise Lost', 'type': 'author', 'tail': 'John Milton'}],
#  [{'head': "'a young boy laying in the grass with his hands on his face'",
#    'type': 'depicts',
#    'tail': 'grass'}],
#  [{'head': "'a young boy laying in the grass with his hands on his face'",
#    'type': 'depicts',
#    'tail': "'a young boy laying in the grass with his hands on his face'"}],
#  [{'head': 'icing', 'type': 'part of', 'tail': 'cake'}],
#  [{'head': 'cake', 'type': 'has part', 'tail': 'icing'}],
#  [{'head': 'icing', 'type': 'facet of', 'tail': 'cake'}],
#  [{'head': 'skylight', 'type': 'part of', 'tail': 'staircase'}],
#  [{'head': 'spiral staircase', 'type': 'has part', 'tail': 'skylight'}],
#  [{'head': 'skylight', 'type': 'part of', 'tail': 'home'}],
#  [{'head': 'fender',
#    'type': 'product or material produced',
#    'tail': 'guitar amplifier'}],
#  [{'head': 'fender',
#    'type': 'product or material produced',
#    'tail': 'amplifier'}],
#  [{'head': 'guitar amplifier', 'type': 'manufacturer', 'tail': 'fender'}],
#  [{'head': "'a black and white photo of a tree'",
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': 'photo of a tree', 'type': 'depicts', 'tail': 'tree'}],
#  [{'head': 'photo of a tree', 'type': 'instance of', 'tail': 'photo'}],
#  [{'head': 'dashboard', 'type': 'part of', 'tail': 'car'}],
#  [{'head': 'car dashboard', 'type': 'has part', 'tail': 'clock'}],
#  [{'head': 'dashboard', 'type': 'part of', 'tail': 'car'},
#   {'head': 'car', 'type': 'has part', 'tail': 'dashboard'}],
#  [{'head': 'cactus', 'type': 'subclass of', 'tail': 'cactus'}],
#  [{'head': 'cactus', 'type': 'parent taxon', 'tail': 'llama'}],
#  [{'head': 'cactus', 'type': 'has part', 'tail': 'llama'}],
#  [{'head': 'black briefcase', 'type': 'has part', 'tail': 'white background'}],
#  [{'head': 'black', 'type': 'opposite of', 'tail': 'white'}],
#  [{'head': 'black briefcase',
#    'type': 'subclass of',
#    'tail': 'white background'}],
#  [{'head': "'a woman sitting on a couch",
#    'type': 'uses',
#    'tail': 'microphone'}],
#  [{'head': "'a woman sitting on a couch holding a microphone'",
#    'type': 'depicts',
#    'tail': 'couch'}],
#  [{'head': 'microphone', 'type': 'part of', 'tail': 'couch'}],
#  [{'head': 'floor', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'floor', 'type': 'part of', 'tail': 'room'},
#   {'head': 'room', 'type': 'has part', 'tail': 'floor'}],
#  [{'head': 'sitting on the floor', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'stockings', 'type': 'different from', 'tail': 'high heels'}],
#  [{'head': 'high heels', 'type': 'has part', 'tail': 'stockings'}],
#  [{'head': 'stockings', 'type': 'different from', 'tail': 'high heels'},
#   {'head': 'high heels', 'type': 'different from', 'tail': 'stockings'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillow', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillows', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'buttons', 'type': 'part of', 'tail': 'dress'}],
#  [{'head': 'button', 'type': 'part of', 'tail': 'dress'}],
#  [{'head': 'buttons', 'type': 'part of', 'tail': 'mannequin'}],
#  [{'head': 'wine', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'wine', 'type': 'part of', 'tail': 'table'},
#   {'head': 'table', 'type': 'has part', 'tail': 'wine'}],
#  [{'head': 'Two glasses of wine', 'type': 'instance of', 'tail': 'wine'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'}],
#  [{'head': 'tie', 'type': 'part of', 'tail': 'suit'}],
#  [{'head': 'suit', 'type': 'has part', 'tail': 'tie'},
#   {'head': 'tie', 'type': 'part of', 'tail': 'suit'}],
#  [{'head': "'a couple of people standing in a room'",
#    'type': 'followed by',
#    'tail': "'a couple of people standing in a room'"}],
#  [{'head': "'a couple of people standing in a room'",
#    'type': 'depicts',
#    'tail': 'couple of people standing in a room'}],
#  [{'head': "'a couple of people standing in a room'",
#    'type': 'depicts',
#    'tail': 'a room'}],
#  [{'head': 'runway', 'type': 'part of', 'tail': 'airport'}],
#  [{'head': 'airport runway', 'type': 'use', 'tail': 'taking off'}],
#  [{'head': 'airport runway', 'type': 'use', 'tail': 'jet taking off'}],
#  [{'head': 'canned food', 'type': 'subclass of', 'tail': 'items'}],
#  [{'head': 'canned food', 'type': 'subclass of', 'tail': 'item'}],
#  [{'head': 'canned food', 'type': 'subclass of', 'tail': 'food'}],
#  [{'head': 'furniture', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'tv', 'type': 'uses', 'tail': 'flat screen'}],
#  [{'head': 'flat screen tv', 'type': 'subclass of', 'tail': 'living room'}],
#  [{'head': 'gym mat', 'type': 'has part', 'tail': 'kettlebell'}],
#  [{'head': 'kettlebell', 'type': 'part of', 'tail': 'gym mat'}],
#  [{'head': 'kettlebell', 'type': 'uses', 'tail': 'gym mat'}],
#  [{'head': 'table', 'type': 'subclass of', 'tail': 'chairs'}],
#  [{'head': 'table', 'type': 'has parts of the class', 'tail': 'chairs'}],
#  [{'head': 'table', 'type': 'has part', 'tail': 'chairs'}],
#  [{'head': 'couch', 'type': 'subclass of', 'tail': 'ottoman'}],
#  [{'head': 'couch', 'type': 'has part', 'tail': 'ottoman'}],
#  [{'head': 'couch', 'type': 'different from', 'tail': 'ottoman'}],
#  [{'head': 'wooden toys', 'type': 'use', 'tail': "child's playroom"}],
#  [{'head': 'wooden toys', 'type': 'part of', 'tail': "child's playroom"}],
#  [{'head': 'wooden toys', 'type': 'subclass of', 'tail': 'playroom'}],
#  [{'head': 'fiber module', 'type': 'has part', 'tail': 'fiber'}],
#  [{'head': 'fiber module', 'type': 'uses', 'tail': 'fiber'}],
#  [{'head': 'fiber', 'type': 'part of', 'tail': 'module'}],
#  [{'head': "'a couple of hoses sitting next to each other'",
#    'type': 'followed by',
#    'tail': "'a couple of hoses sitting next to each other'"}],
#  [{'head': "'a couple of hoses sitting next to each other'",
#    'type': 'part of',
#    'tail': "'a couple of hoses sitting next to each other'"}],
#  [{'head': "'a couple of hoses sitting next to each other'",
#    'type': 'instance of',
#    'tail': 'hoses'}],
#  [{'head': 'chair', 'type': 'part of', 'tail': 'chair'}],
#  [{'head': 'chair', 'type': 'subclass of', 'tail': 'chair'}],
#  [{'head': "'a cartoon of a man sitting on top of a chair'",
#    'type': 'genre',
#    'tail': 'cartoon'}],
#  [{'head': 'bed room', 'type': 'has part', 'tail': 'bed'}],
#  [{'head': 'bed room', 'type': 'has part', 'tail': 'bed'},
#   {'head': 'bed', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'earrings', 'type': 'part of', 'tail': 'hand'}],
#  [{'head': 'earring', 'type': 'part of', 'tail': 'hand'}],
#  [{'head': 'earrings', 'type': 'part of', 'tail': 'hand'},
#   {'head': 'hand', 'type': 'has part', 'tail': 'earrings'}],
#  [{'head': 'roofing', 'type': 'has part', 'tail': 'sheets'}],
#  [{'head': 'roofing sheets', 'type': 'part of', 'tail': 'shelf'}],
#  [{'head': 'roofing', 'type': 'uses', 'tail': 'sheets'}],
#  [{'head': 'waterfall', 'type': 'part of', 'tail': 'forest'}],
#  [{'head': 'waterfall', 'type': 'location', 'tail': 'forest'}],
#  [{'head': 'forest', 'type': 'has part', 'tail': 'waterfall'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillow', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'comforter', 'type': 'part of', 'tail': 'bed'},
#   {'head': 'pillows', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': "'a black and white photo of a harbor'",
#    'type': 'depicts',
#    'tail': 'harbor'}],
#  [{'head': 'harbor', 'type': 'subclass of', 'tail': 'black and white photo'}],
#  [{'head': 'harbor', 'type': 'subclass of', 'tail': 'black and white'}],
#  [{'head': 'soccer', 'type': 'subclass of', 'tail': 'game'}],
#  [{'head': 'soccer', 'type': 'instance of', 'tail': 'game'}],
#  [{'head': 'soccer', 'type': 'subclass of', 'tail': 'game of soccer'}],
#  [{'head': 'beer', 'type': 'has part', 'tail': 'glass'}],
#  [{'head': 'beer', 'type': 'has part', 'tail': 'glasses'}],
#  [{'head': 'beer', 'type': 'uses', 'tail': 'glass'}],
#  [{'head': 'Holiday Inn', 'type': 'subclass of', 'tail': 'hotel'}],
#  [{'head': 'hotel and suites', 'type': 'subclass of', 'tail': 'hotel'}],
#  [{'head': 'hotel and suites', 'type': 'subclass of', 'tail': 'inn'}],
#  [{'head': 'red shirt', 'type': 'has part', 'tail': 'black skirt'}],
#  [{'head': 'Red shirt', 'type': 'has part', 'tail': 'black skirt'}],
#  [{'head': 'Red shirt', 'type': 'has part', 'tail': 'skirt'}],
#  [{'head': 'hiking boots', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'hiking boots', 'type': 'use', 'tail': 'hiking'}],
#  [{'head': 'hiking boot', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'sports car', 'type': 'location', 'tail': 'dirt lot'}],
#  [{'head': 'blue sports car', 'type': 'location', 'tail': 'dirt lot'}],
#  [{'head': "'a blue sports car", 'type': 'location', 'tail': 'dirt lot'}],
#  [{'head': "'a man standing in front of a red barn'",
#    'type': 'depicts',
#    'tail': 'red barn'}],
#  [{'head': "'a man standing in front of a red barn'",
#    'type': 'main subject',
#    'tail': 'red barn'}],
#  [{'head': "'a man standing in front of a red barn'",
#    'type': 'depicts',
#    'tail': 'red barn'},
#   {'head': 'red barn',
#    'type': 'depicts',
#    'tail': "'a man standing in front of a red barn'"}],
#  [{'head': 'seattle', 'type': 'instance of', 'tail': 'city'}],
#  [{'head': 'an aerial view of the city of seattle',
#    'type': 'depicts',
#    'tail': 'seattle'}],
#  [{'head': 'city of seattle',
#    'type': 'located in the administrative territorial entity',
#    'tail': 'seattle'}],
#  [{'head': 'tent', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'tent', 'type': 'depicts', 'tail': 'white'}],
#  [{'head': "'an image of a tent on a white background'",
#    'type': 'depicts',
#    'tail': 'tent'}],
#  [{'head': "'a sign that says home is where my plants are'",
#    'type': 'instance of',
#    'tail': 'sign'}],
#  [{'head': "'A sign that says home is where my plants are'",
#    'type': 'instance of',
#    'tail': 'sign'}],
#  [{'head': "'a sign that says home is where my plants are'",
#    'type': 'is a list of',
#    'tail': 'sign'}],
#  [{'head': "'a man in a pink shirt and blue pants'",
#    'type': 'depicts',
#    'tail': 'pink'}],
#  [{'head': 'Pink shirt', 'type': 'followed by', 'tail': 'blue pants'}],
#  [{'head': "'a man in a pink shirt and blue pants'",
#    'type': 'depicts',
#    'tail': 'blue pants'}],
#  [{'head': 'two women looking at shoes in a store',
#    'type': 'depicts',
#    'tail': 'store'}],
#  [{'head': 'shoes', 'type': 'part of', 'tail': 'store'}],
#  [{'head': 'two women looking at shoes', 'type': 'depicts', 'tail': 'store'}],
#  [{'head': 'American flag',
#    'type': 'applies to jurisdiction',
#    'tail': 'american'}],
#  [{'head': 'flag', 'type': 'applies to jurisdiction', 'tail': 'american'}],
#  [{'head': 'american flag', 'type': 'depicts', 'tail': 'street'}],
#  [{'head': 'motorcycle', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'motorcycle', 'type': 'color', 'tail': 'white'}],
#  [{'head': 'motorcycle', 'type': 'has part', 'tail': 'white background'}],
#  [{'head': 'building', 'type': 'depicts', 'tail': 'children'}],
#  [{'head': 'building', 'type': 'occupant', 'tail': 'children'}],
#  [{'head': 'building', 'type': 'has part', 'tail': 'children'}],
#  [{'head': 'herd', 'type': 'has part', 'tail': 'deer'}],
#  [{'head': 'field', 'type': 'has part', 'tail': 'grass'}],
#  [{'head': 'field', 'type': 'subclass of', 'tail': 'grass'}],
#  [{'head': "'a woman in a long white dress'",
#    'type': 'depicts',
#    'tail': 'dress'}],
#  [{'head': "'a woman in a long white dress'",
#    'type': 'depicts',
#    'tail': 'white dress'}],
#  [{'head': 'a woman in a long white dress',
# ...
#  [{'head': 'guitar', 'type': 'use', 'tail': 'playing a guitar'}],
#  [{'head': 'guitar', 'type': 'location', 'tail': 'dock'}],
#  [{'head': 'drawers', 'type': 'part of', 'tail': 'box'}],
#  [{'head': 'box', 'type': 'has part', 'tail': 'drawers'}],
#  [{'head': 'box', 'type': 'has part', 'tail': 'drawers'},
#   {'head': 'drawers', 'type': 'part of', 'tail': 'box'}],
#  [{'head': 'adidas',
#    'type': 'product or material produced',
#    'tail': 'running shoe'}],
#  [{'head': 'adidas', 'type': 'product or material produced', 'tail': 'shoe'}],
#  [{'head': 'Adidas',
#    'type': 'product or material produced',
#    'tail': 'running shoe'}],
#  [{'head': 'boss', 'type': 'product or material produced', 'tail': 'cologne'}],
#  [{'head': 'boss bottled',
#    'type': 'product or material produced',
#    'tail': 'cologne'}],
#  [{'head': 'boss', 'type': 'field of this occupation', 'tail': 'cologne'},
#   {'head': 'cologne', 'type': 'practiced by', 'tail': 'boss'}],
#  [{'head': 'pillows', 'type': 'part of', 'tail': 'couch'}],
#  [{'head': 'couch', 'type': 'has part', 'tail': 'pillows'}],
#  [{'head': 'pillow', 'type': 'part of', 'tail': 'couch'}],
#  [{'head': "'three glass jellys sitting on top of a table'",
#    'type': 'depicts',
#    'tail': 'jellys'}],
#  [{'head': "'three glass jellys sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'jellys'}],
#  [{'head': "'three glass jellys sitting on top of a table'",
#    'type': 'main subject',
#    'tail': 'jellys'}],
#  [{'head': 'three pieces of jewelry on a white surface',
#    'type': 'facet of',
#    'tail': 'white'}],
#  [{'head': 'three pieces of jewelry on a white surface',
#    'type': 'subclass of',
#    'tail': 'jewelry'}],
#  [{'head': 'three pieces of jewelry on a white surface',
#    'type': 'facet of',
#    'tail': 'white surface'}],
#  [{'head': 'international space station',
#    'type': 'continent',
#    'tail': 'earth'}],
#  [{'head': 'international space station',
#    'type': 'location',
#    'tail': 'earth'}],
#  [{'head': 'space station', 'type': 'part of', 'tail': 'earth'}],
#  [{'head': 'two female cricket players walking on a field',
#    'type': 'sport',
#    'tail': 'cricket'}],
#  [{'head': 'cricket', 'type': 'uses', 'tail': 'field'},
#   {'head': 'field', 'type': 'sport', 'tail': 'cricket'}],
#  [{'head': 'walking on a field', 'type': 'sport', 'tail': 'cricket'}],
#  [{'head': 'campus surrounded by trees',
#    'type': 'subclass of',
#    'tail': 'aerial view'}],
#  [{'head': 'campus surrounded by trees',
#    'type': 'instance of',
#    'tail': 'aerial view'}],
#  [{'head': 'campus surrounded by trees',
#    'type': 'instance of',
#    'tail': 'aerial'}],
#  [{'head': 'beer', 'type': 'has part', 'tail': 'cans'}],
#  [{'head': 'beer', 'type': 'different from', 'tail': 'cans'}],
#  [{'head': 'beer', 'type': 'has part', 'tail': 'cans of beer'}],
#  [{'head': 'fishnet', 'type': 'subclass of', 'tail': 'stockings'}],
#  [{'head': 'tights', 'type': 'subclass of', 'tail': 'stockings'}],
#  [{'head': 'fishnet', 'type': 'subclass of', 'tail': 'tights'}],
#  [{'head': 'picture inside of it', 'type': 'subclass of', 'tail': 'jar'}],
#  [{'head': "'a glass jar with a picture inside of it'",
#    'type': 'instance of',
#    'tail': 'jar'}],
#  [{'head': "'a glass jar with a picture inside of it'",
#    'type': 'subclass of',
#    'tail': 'jar'}],
#  [{'head': "'a woman wearing a black and gold dress'",
#    'type': 'instance of',
#    'tail': 'dress'}],
#  [{'head': "'a woman wearing a black and gold dress'",
#    'type': 'depicts',
#    'tail': 'dress'}],
#  [{'head': "'a woman wearing a black and gold dress",
#    'type': 'instance of',
#    'tail': 'dress'}],
#  [{'head': "'a girl in a maroon shirt",
#    'type': 'instrument',
#    'tail': 'clarinet'}],
#  [{'head': "'a girl in a maroon shirt playing a clarinet'",
#    'type': 'instrument',
#    'tail': 'clarinet'}],
#  [{'head': 'girl in a maroon shirt',
#    'type': 'instrument',
#    'tail': 'clarinet'}],
#  [{'head': 'bridesmaid dress', 'type': 'subclass of', 'tail': 'dress'}],
#  [{'head': 'dress', 'type': 'used by', 'tail': 'bridesmaid'}],
#  [{'head': 'bridesmaid dress', 'type': 'use', 'tail': 'bridesmaid'}],
#  [{'head': 'statue', 'type': 'depicts', 'tail': 'dog'}],
#  [{'head': 'statue of a dog', 'type': 'depicts', 'tail': 'dog'}],
#  [{'head': "statue of a dog with a butterfly on it's wing",
#    'type': 'depicts',
#    'tail': 'dog'}],
#  [{'head': 'the experis manpower group logo',
#    'type': 'instance of',
#    'tail': 'logo'}],
#  [{'head': "'the experis manpower group logo'",
#    'type': 'instance of',
#    'tail': 'logo'}],
#  [{'head': 'the experis manpower group',
#    'type': 'instance of',
#    'tail': 'logo'}],
#  [{'head': "'a group of men standing on top of a boat'",
#    'type': 'depicts',
#    'tail': 'boat'}],
#  [{'head': 'John F. Kennedy School of Government',
#    'type': 'part of',
#    'tail': 'Harvard University'}],
#  [{'head': "'a group of men standing on top of a boat'",
#    'type': 'main subject',
#    'tail': 'boat'}],
#  [{'head': 'cleaning products', 'type': 'part of', 'tail': 'store'}],
#  [{'head': 'cleaning product', 'type': 'use', 'tail': 'cleaning'}],
#  [{'head': 'cleaning products', 'type': 'subclass of', 'tail': 'store'}],
#  [{'head': 'John F. Kennedy School of Government',
#    'type': 'part of',
#    'tail': 'Harvard University'}],
#  [{'head': "'a bunch of boats that are sitting in the water'",
#    'type': 'instance of',
#    'tail': 'film'}],
#  [{'head': 'John F. Kennedy',
#    'type': 'position held',
#    'tail': 'Secretary of Defense'}],
#  [{'head': 'white shirt', 'type': 'has part', 'tail': 'pants'}],
#  [{'head': 'white shirt', 'type': 'followed by', 'tail': 'pants'}],
#  [{'head': 'white shirt', 'type': 'subclass of', 'tail': 'pants'}],
#  [{'head': "'a group of people standing around a turkey'",
#    'type': 'depicts',
#    'tail': 'turkey'}],
#  [{'head': "'a group of people standing around a turkey'",
#    'type': 'main subject',
#    'tail': 'turkey'}],
#  [{'head': 'Turkey', 'type': 'named after', 'tail': 'turkey'}],
#  [{'head': 'usb cable', 'type': 'connects with', 'tail': 'cell phone'}],
#  [{'head': 'usb', 'type': 'connects with', 'tail': 'cell phone'}],
#  [{'head': 'cell phone', 'type': 'connects with', 'tail': 'usb cable'}],
#  [{'head': 'skull', 'type': 'part of', 'tail': 'ring'}],
#  [{'head': 'skull', 'type': 'use', 'tail': 'ring'}],
#  [{'head': "'a close up of a ring with a skull on it'",
#    'type': 'depicts',
#    'tail': 'ring'}],
#  [{'head': "artist's rendering", 'type': 'depicts', 'tail': 'building'}],
#  [{'head': 'street',
#    'type': 'located in the administrative territorial entity',
#    'tail': 'city'}],
#  [{'head': 'street', 'type': 'different from', 'tail': 'building'}],
#  [{'head': 'graph', 'type': 'depicts', 'tail': 'number of people'}],
#  [{'head': 'graph', 'type': 'depicts', 'tail': 'number of people'},
#   {'head': 'number of people', 'type': 'depicts', 'tail': 'graph'}],
#  [{'head': 'graph',
#    'type': 'depicts',
#    'tail': 'number of people in the city'}],
#  [{'head': 'crackers', 'type': 'subclass of', 'tail': 'bowl'}],
#  [{'head': 'cracker', 'type': 'subclass of', 'tail': 'bowl'}],
#  [{'head': 'crackers', 'type': 'part of', 'tail': 'bowl'}],
#  [{'head': 'cutting a ribbon', 'type': 'location', 'tail': 'room'}],
#  [{'head': 'cutting a ribbon', 'type': 'part of', 'tail': 'room'}],
#  [{'head': 'Cutting a ribbon', 'type': 'location', 'tail': 'room'}],
#  [{'head': 'grass', 'type': 'subclass of', 'tail': 'house'}],
#  [{'head': 'grass', 'type': 'part of', 'tail': 'house'}],
#  [{'head': 'house that is in the grass',
#    'type': 'named after',
#    'tail': 'grass'}],
#  [{'head': 'mountain range', 'type': 'subclass of', 'tail': 'photo'}],
#  [{'head': "'a black and white photo of a mountain range'",
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': "'a black and white photo of a mountain range'",
#    'type': 'depicts',
#    'tail': 'mountain range'}],
#  [{'head': 'clock tower', 'type': 'part of', 'tail': 'building'}],
#  [{'head': 'clock tower', 'type': 'subclass of', 'tail': 'building'}],
#  [{'head': 'clock tower', 'type': 'subclass of', 'tail': 'stone building'}],
#  [{'head': 'table', 'type': 'part of', 'tail': 'patio'}],
#  [{'head': 'patio', 'type': 'part of', 'tail': 'house'}],
#  [{'head': 'patio', 'type': 'has parts of the class', 'tail': 'table'}],
#  [{'head': 'crib', 'type': 'used by', 'tail': 'baby'}],
#  [{'head': 'crib', 'type': 'part of', 'tail': 'baby'}],
#  [{'head': 'white', 'type': 'opposite of', 'tail': 'black'}],
#  [{'head': 'chewy treat', 'type': 'subclass of', 'tail': 'chewy'}],
#  [{'head': 'chewy', 'type': 'subclass of', 'tail': 'treat'}],
#  [{'head': 'chewy treats', 'type': 'subclass of', 'tail': 'chewy'}],
#  [{'head': 'tarmac', 'type': 'part of', 'tail': 'airport'}],
#  [{'head': 'airport', 'type': 'has part', 'tail': 'tarmac'}],
#  [{'head': 'jetliner', 'type': 'location', 'tail': 'airport'}],
#  [{'head': 'barrel', 'type': 'use', 'tail': 'beer'}],
#  [{'head': 'barrel', 'type': 'part of', 'tail': 'beer'}],
#  [{'head': 'barrel', 'type': 'facet of', 'tail': 'beer'}],
#  [{'head': 'guitar', 'type': 'use', 'tail': 'playing'}],
#  [{'head': 'guitars', 'type': 'subclass of', 'tail': 'group of people'}],
#  [{'head': 'guitars', 'type': 'part of', 'tail': 'group of people'}],
#  [{'head': 'toilet', 'type': 'part of', 'tail': 'bathroom'}],
#  [{'head': 'sink', 'type': 'part of', 'tail': 'toilet'}],
#  [{'head': 'bathroom', 'type': 'has part', 'tail': 'toilet'}],
#  [{'head': 'sunglasses', 'type': 'part of', 'tail': 'table'}],
#  [{'head': 'sunglasses', 'type': 'location', 'tail': 'table'}],
#  [{'head': "'a pair of sunglasses sitting on top of a table'",
#    'type': 'instance of',
#    'tail': 'sunglasses'}],
#  [{'head': 'couch', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'living room', 'type': 'has part', 'tail': 'window'}],
#  [{'head': 'living room', 'type': 'has part', 'tail': 'couch'}],
#  [{'head': "'a painting of a man in a black hat'",
#    'type': 'instance of',
#    'tail': 'painting'}],
#  [{'head': 'painting of a man in a black hat',
#    'type': 'depicts',
#    'tail': 'black hat'}],
#  [{'head': 'painting of a man in a black hat',
#    'type': 'depicts',
#    'tail': 'a man in a black hat'}],
#  [{'head': 'tubes', 'type': 'has part', 'tail': 'plastic'}],
#  [{'head': 'clear plastic tubes', 'type': 'has part', 'tail': 'blue'}],
#  [{'head': 'blue', 'type': 'facet of', 'tail': 'blue'}],
#  [{'head': "'a woman in a white lingerie posing for a picture'",
#    'type': 'main subject',
#    'tail': 'lingerie'}],
#  [{'head': "'a woman in a white lingerie posing for a picture'",
#    'type': 'depicts',
#    'tail': 'lingerie'}],
#  [{'head': "'a woman in a white lingerie posing for a picture'",
#    'type': 'instance of',
#    'tail': 'picture'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'},
#   {'head': 'closet', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed'}],
#  [{'head': 'tie', 'type': 'has part', 'tail': 'checkered'}],
#  [{'head': 'checkered', 'type': 'subclass of', 'tail': 'tie'}],
#  [{'head': 'checkered tie', 'type': 'has part', 'tail': 'checkered'}],
#  [{'head': 'living room', 'type': 'subclass of', 'tail': 'group of people'}],
#  [{'head': 'living room', 'type': 'subclass of', 'tail': 'group'}],
#  [{'head': 'living room',
#    'type': 'subclass of',
#    'tail': 'group of people sitting around a living room'}],
#  [{'head': "'a black and white photo of a man standing next to a car'",
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': 'photo of a man standing next to a car',
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': "'a black and white photo",
#    'type': 'instance of',
#    'tail': 'photo'}],
#  [{'head': "'a close up of a bunch of flowers on a table'",
#    'type': 'instance of',
#    'tail': 'picture'}],
#  [{'head': "'a close up of a bunch of flowers on a table'",
#    'type': 'depicts',
#    'tail': 'flower'}],
#  [{'head': "'a close up of a bunch of flowers on a table'",
#    'type': 'depicts',
#    'tail': 'flowers'}],
#  [{'head': 'button', 'type': 'subclass of', 'tail': 'close up'}],
#  [{'head': 'button', 'type': 'subclass of', 'tail': 'camera'}],
#  [{'head': 'button', 'type': 'use', 'tail': 'close up'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'bed room', 'type': 'has part', 'tail': 'bed'}],
#  [{'head': 'flat screen tv', 'type': 'part of', 'tail': 'bed room'}],
#  [{'head': 'Monster Face', 'type': 'instance of', 'tail': 'poster'}],
#  [{'head': "'a poster for a concert with a monster face on it'",
#    'type': 'depicts',
#    'tail': 'monster face'}],
#  [{'head': "'a poster for a concert with a monster face on it'",
#    'type': 'instance of',
#    'tail': 'poster'}],
#  [{'head': "'a woman standing in front of a brick wall'",
#    'type': 'depicts',
#    'tail': 'brick wall'}],
#  [{'head': "'a woman standing in front of a brick wall'",
#    'type': 'depicts',
#    'tail': "'a woman standing in front of a brick wall'"}],
#  [{'head': "'a woman standing in front of a brick wall'",
#    'type': 'depicts',
#    'tail': 'a brick wall'}],
#  [{'head': 'couch', 'type': 'part of', 'tail': 'living room'}],
#  [{'head': 'living room', 'type': 'has part', 'tail': 'couch'}],
#  [{'head': 'living room', 'type': 'has parts of the class', 'tail': 'couch'}],
#  [{'head': 'tower', 'type': 'part of', 'tail': 'street'}],
#  [{'head': 'tower', 'type': 'different from', 'tail': 'street'}],
#  [{'head': 'Tower of the Americas',
#    'type': 'located in the administrative territorial entity',
#    'tail': 'Mexico City'}],
#  [{'head': 'flower', 'type': 'part of', 'tail': 'bird'}],
#  [{'head': 'flowers', 'type': 'part of', 'tail': 'birds'}],
#  [{'head': 'flowers', 'type': 'used by', 'tail': 'birds'}],
#  [{'head': 'motherboard', 'type': 'part of', 'tail': 'computer'}],
#  [{'head': 'computer', 'type': 'has part', 'tail': 'motherboard'},
#   {'head': 'motherboard', 'type': 'part of', 'tail': 'computer'}],
#  [{'head': 'motherboard', 'type': 'part of', 'tail': 'computer'},
#   {'head': 'computer', 'type': 'has part', 'tail': 'motherboard'}],
#  [{'head': 'reviews', 'type': 'part of', 'tail': 'website'}],
#  [{'head': 'review', 'type': 'part of', 'tail': 'website'}],
#  [{'head': 'reviews', 'type': 'facet of', 'tail': 'website'}],
#  [{'head': 'bmw', 'type': 'subclass of', 'tail': 'suv'}],
#  [{'head': 'Bmw', 'type': 'manufacturer', 'tail': 'bmw'}],
#  [{'head': "'a black bmw suv", 'type': 'manufacturer', 'tail': 'bmw'}],
#  [{'head': 'plates', 'type': 'subclass of', 'tail': 'silverware'}],
#  [{'head': 'silverware', 'type': 'has part', 'tail': 'plates'}],
#  [{'head': 'plates', 'type': 'different from', 'tail': 'silverware'}],
#  [{'head': 'bunk bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'bunk bed', 'type': 'subclass of', 'tail': 'bedroom'}],
#  [{'head': 'bed', 'type': 'part of', 'tail': 'bedroom'}],
#  [{'head': 'statue', 'type': 'depicts', 'tail': 'police officer'}],
#  [{'head': 'police officer', 'type': 'depicts', 'tail': 'statue'}],
#  [{'head': 'police officer', 'type': 'has part', 'tail': 'statue'}],
#  [{'head': 'metal', 'type': 'subclass of', 'tail': 'object'}],
#  [{'head': 'metal object', 'type': 'has part', 'tail': 'white'}],
#  [{'head': 'metal object', 'type': 'has part', 'tail': 'white background'}],
#  [{'head': 'Bottle', 'type': 'subclass of', 'tail': 'bottles'}],
#  [{'head': 'Bottle', 'type': 'part of', 'tail': 'bottles'}],
#  [{'head': 'Bottles', 'type': 'subclass of', 'tail': 'bottles'}],
#  [{'head': 'skull', 'type': 'part of', 'tail': 'dinosaur'}],
#  [{'head': 'skull mounted on a brick wall',
#    'type': 'depicts',
#    'tail': 'dinosaur'}],
#  [{'head': 'dinosaur skull', 'type': 'part of', 'tail': 'brick wall'}],
#  [{'head': 'gold chain', 'type': 'part of', 'tail': 'hand'}],
#  [{'head': "'a hand holding a small purple elephant",
#    'type': 'instance of',
#    'tail': 'gold chain'}],
#  [{'head': "'a hand holding a small purple elephant on a gold chain'",
#    'type': 'depicts',
#    'tail': 'elephant'}],
#  [{'head': 'chocolate', 'type': 'has part', 'tail': 'egg'}],
#  [{'head': 'egg', 'type': 'has part', 'tail': 'chocolate'}],
#  [{'head': 'chocolate', 'type': 'has part', 'tail': 'eggs'}],
#  [{'head': 'leather', 'type': 'use', 'tail': 'strap'}],
#  ...]

# %%
df_rebel=pd.DataFrame({'url':url_list,'triplet':triplet_list})
df_rebel.to_csv('rebel_babelscape_rebel-large.csv',index=False)
df_rebel.head()
# Out:
#                                                  url  \
# 0  https://www.equipmentsalesandsurplus.com/v/vsp...
# 1  https://www.equipmentsalesandsurplus.com/v/vsp...
# 2  https://www.equipmentsalesandsurplus.com/v/vsp...
# 3  https://texasfurniturehut.com/images/thumbs/00...
# 4  https://texasfurniturehut.com/images/thumbs/00...
#
#                                              triplet
# 0  [{'head': 'table sawing', 'type': 'subclass of...
# 1  [{'head': 'table sawing machine', 'type': 'sub...
# 2  [{'head': 'table sawing machine', 'type': 'has...
# 3  [{'head': 'recliner', 'type': 'subclass of', '...
# 4  [{'head': 'leather', 'type': 'subclass of', 't...
