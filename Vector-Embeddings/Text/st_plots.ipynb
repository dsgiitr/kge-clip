# %%
# !pip install pandas matplotlib scikit-learn umap-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.12-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.12 umap-learn-0.5.6

# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA

# Load the embeddings
df_embeddings = pd.read_csv('short_caption_embeddings-2.csv')

# Drop rows with NaN values
df_embeddings.dropna(inplace=True)

# Extract embeddings and captions
embeddings = df_embeddings.iloc[:, :-1].values
captions = df_embeddings['prompt'].values

# Perform PCA
pca = PCA(n_components=3)
pca_result = pca.fit_transform(embeddings)

# Create a DataFrame for plotting
df_pca = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2', 'PCA3'])
df_pca['caption'] = captions

# Plot PCA results
fig = px.scatter_3d(df_pca, x='PCA1', y='PCA2', z='PCA3', hover_data=['caption'], title='3D PCA of Embeddings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9d3481e-8035-4b63-9077-c56f3d015ae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9d3481e-8035-4b63-9077-c56f3d015ae4")) {                    Plotly.newPlot(                        "c9d3481e-8035-4b63-9077-c56f3d015ae4",                        [{"customdata":[["a golf course overlooking the ocean"],["a pair of earrings with saturn on them"],["a row of lettuce growing in a greenhouse"],["a brown and red wetsuit with a logo on the chest"],["a large herd of sheep in a fenced in area"],["a close up of a person wearing a suit and tie"],["a close up of a metal disc on a white background"],["a humpback whale spouting water in the ocean"],["a group of people riding on the backs of horses"],["the interior of a car is shown"],["a group of people standing around a child on a skateboard"],["the cover of grimm tales of terror and h h holmes"],["a painting of a boy and his dog"],["a card with a bird and a house on it"],["a map of the world is shown on a wall"],["an old typewriter sitting on top of a table"],["a collage of photos of a bedroom and bathroom"],["a diamond ring on a white background"],["black horse off road - d | running boards with black wheels - a picture of a black"],["a close up of a bracelet on a white background"],["a little boy standing in a pool with his hands in the air"],["a black sports car driving on a track"],["a young boy in a red shirt and a hat eating a piece of cake"],["a pair of bearings on a white surface"],["a woman standing in a field of tall grass"],["a piece of meat sitting on top of tin foil"],["a pair of tires on a white background"],["a white tablet computer sitting on top of a white table"],["a bunch of plants that are on a shelf"],["a baseball card with a baseball player holding a bat"],["a row of apartment buildings next to a street light"],["a bunch of flowers sitting on top of a table"],["a man working on a large pipe in a factory"],["a stethoscope with a flower attached to it"],["a man in an orange shirt holding a gun near a tree"],["a fuel pump with a hose attached to it"],["a drawing of a woman sitting on top of a hill"],["a close up of a drawing of a building"],["a woman sitting on top of a yellow chair"],["a couple of people that are holding a trophy"],["a group of people standing next to each other"],["a pair of earrings with green stones"],["a group of people sitting outside of a restaurant at night"],["a bedroom with a bed, desk, and bookshelf"],["a black telephone sitting on top of a wooden table"],["a close up of a wedding ring on a table"],["a woman in a white bikini and panties"],["a bar chart that shows the number of people in the united states"],["a man standing in front of a group of people"],["a mannequin wearing a multicolored dress"],["a close up of a dessert on a plate"],["a train traveling through a lush green countryside"],["an electronic device with a clock on top of it"],["a close up of a cell phone on a pole"],["a woman in a red lingerie posing for a picture"],["a view of a city from a bridge"],["a group of men standing in front of a table of food"],["a white bracelet with a blue flower on it"],["a single engine plane sitting on a runway"],["a woman standing in front of a wall"],["a staircase leading up to a second floor"],["a kitchen with a stove top oven sitting next to a window"],["a black and white photo of a man in a tuxedo"],["a living room filled with furniture and a kitchen in the background"],["a bed sitting in a bedroom next to a window"],["a large cargo ship in the water near a dock"],["a living room with a couch and a window"],["a girl's athletic shoe with pink laces"],["a bird's eye view of a beach and water"],["a kitchen with white cabinets and a b ...

# %%
import umap

# Load the embeddings
df_embeddings = pd.read_csv('short_caption_embeddings-2.csv')

# Drop rows with NaN values
df_embeddings.dropna(inplace=True)

# Extract embeddings and captions
embeddings = df_embeddings.iloc[:, :-1].values
captions = df_embeddings['prompt'].values

# Perform UMAP
umap_model = umap.UMAP(n_components=3)
umap_result = umap_model.fit_transform(embeddings)

# Create a DataFrame for plotting
df_umap = pd.DataFrame(umap_result, columns=['UMAP1', 'UMAP2', 'UMAP3'])
df_umap['caption'] = captions

# Plot UMAP results
fig = px.scatter_3d(df_umap, x='UMAP1', y='UMAP2', z='UMAP3', hover_data=['caption'], title='3D UMAP of Embeddings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cadc7c20-aa4f-4de5-b56e-d0c27ff5c58a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cadc7c20-aa4f-4de5-b56e-d0c27ff5c58a")) {                    Plotly.newPlot(                        "cadc7c20-aa4f-4de5-b56e-d0c27ff5c58a",                        [{"customdata":[["a golf course overlooking the ocean"],["a pair of earrings with saturn on them"],["a row of lettuce growing in a greenhouse"],["a brown and red wetsuit with a logo on the chest"],["a large herd of sheep in a fenced in area"],["a close up of a person wearing a suit and tie"],["a close up of a metal disc on a white background"],["a humpback whale spouting water in the ocean"],["a group of people riding on the backs of horses"],["the interior of a car is shown"],["a group of people standing around a child on a skateboard"],["the cover of grimm tales of terror and h h holmes"],["a painting of a boy and his dog"],["a card with a bird and a house on it"],["a map of the world is shown on a wall"],["an old typewriter sitting on top of a table"],["a collage of photos of a bedroom and bathroom"],["a diamond ring on a white background"],["black horse off road - d | running boards with black wheels - a picture of a black"],["a close up of a bracelet on a white background"],["a little boy standing in a pool with his hands in the air"],["a black sports car driving on a track"],["a young boy in a red shirt and a hat eating a piece of cake"],["a pair of bearings on a white surface"],["a woman standing in a field of tall grass"],["a piece of meat sitting on top of tin foil"],["a pair of tires on a white background"],["a white tablet computer sitting on top of a white table"],["a bunch of plants that are on a shelf"],["a baseball card with a baseball player holding a bat"],["a row of apartment buildings next to a street light"],["a bunch of flowers sitting on top of a table"],["a man working on a large pipe in a factory"],["a stethoscope with a flower attached to it"],["a man in an orange shirt holding a gun near a tree"],["a fuel pump with a hose attached to it"],["a drawing of a woman sitting on top of a hill"],["a close up of a drawing of a building"],["a woman sitting on top of a yellow chair"],["a couple of people that are holding a trophy"],["a group of people standing next to each other"],["a pair of earrings with green stones"],["a group of people sitting outside of a restaurant at night"],["a bedroom with a bed, desk, and bookshelf"],["a black telephone sitting on top of a wooden table"],["a close up of a wedding ring on a table"],["a woman in a white bikini and panties"],["a bar chart that shows the number of people in the united states"],["a man standing in front of a group of people"],["a mannequin wearing a multicolored dress"],["a close up of a dessert on a plate"],["a train traveling through a lush green countryside"],["an electronic device with a clock on top of it"],["a close up of a cell phone on a pole"],["a woman in a red lingerie posing for a picture"],["a view of a city from a bridge"],["a group of men standing in front of a table of food"],["a white bracelet with a blue flower on it"],["a single engine plane sitting on a runway"],["a woman standing in front of a wall"],["a staircase leading up to a second floor"],["a kitchen with a stove top oven sitting next to a window"],["a black and white photo of a man in a tuxedo"],["a living room filled with furniture and a kitchen in the background"],["a bed sitting in a bedroom next to a window"],["a large cargo ship in the water near a dock"],["a living room with a couch and a window"],["a girl's athletic shoe with pink laces"],["a bird's eye view of a beach and water"],["a kitchen with white cabinets and a b ...

# %%
from sklearn.manifold import TSNE

# Load the embeddings
df_embeddings = pd.read_csv('short_caption_embeddings-2.csv')

# Drop rows with NaN values
df_embeddings.dropna(inplace=True)

# Extract embeddings and captions
embeddings = df_embeddings.iloc[:, :-1].values
captions = df_embeddings['prompt'].values

# Perform t-SNE
tsne = TSNE(n_components=3, random_state=42)
tsne_result = tsne.fit_transform(embeddings)

# Create a DataFrame for plotting
df_tsne = pd.DataFrame(tsne_result, columns=['TSNE1', 'TSNE2', 'TSNE3'])
df_tsne['caption'] = captions

# Plot t-SNE results
fig = px.scatter_3d(df_tsne, x='TSNE1', y='TSNE2', z='TSNE3', hover_data=['caption'], title='3D t-SNE of Embeddings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="37c4b259-bb2d-4bf8-9904-87bab95a0c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37c4b259-bb2d-4bf8-9904-87bab95a0c8f")) {                    Plotly.newPlot(                        "37c4b259-bb2d-4bf8-9904-87bab95a0c8f",                        [{"customdata":[["a golf course overlooking the ocean"],["a pair of earrings with saturn on them"],["a row of lettuce growing in a greenhouse"],["a brown and red wetsuit with a logo on the chest"],["a large herd of sheep in a fenced in area"],["a close up of a person wearing a suit and tie"],["a close up of a metal disc on a white background"],["a humpback whale spouting water in the ocean"],["a group of people riding on the backs of horses"],["the interior of a car is shown"],["a group of people standing around a child on a skateboard"],["the cover of grimm tales of terror and h h holmes"],["a painting of a boy and his dog"],["a card with a bird and a house on it"],["a map of the world is shown on a wall"],["an old typewriter sitting on top of a table"],["a collage of photos of a bedroom and bathroom"],["a diamond ring on a white background"],["black horse off road - d | running boards with black wheels - a picture of a black"],["a close up of a bracelet on a white background"],["a little boy standing in a pool with his hands in the air"],["a black sports car driving on a track"],["a young boy in a red shirt and a hat eating a piece of cake"],["a pair of bearings on a white surface"],["a woman standing in a field of tall grass"],["a piece of meat sitting on top of tin foil"],["a pair of tires on a white background"],["a white tablet computer sitting on top of a white table"],["a bunch of plants that are on a shelf"],["a baseball card with a baseball player holding a bat"],["a row of apartment buildings next to a street light"],["a bunch of flowers sitting on top of a table"],["a man working on a large pipe in a factory"],["a stethoscope with a flower attached to it"],["a man in an orange shirt holding a gun near a tree"],["a fuel pump with a hose attached to it"],["a drawing of a woman sitting on top of a hill"],["a close up of a drawing of a building"],["a woman sitting on top of a yellow chair"],["a couple of people that are holding a trophy"],["a group of people standing next to each other"],["a pair of earrings with green stones"],["a group of people sitting outside of a restaurant at night"],["a bedroom with a bed, desk, and bookshelf"],["a black telephone sitting on top of a wooden table"],["a close up of a wedding ring on a table"],["a woman in a white bikini and panties"],["a bar chart that shows the number of people in the united states"],["a man standing in front of a group of people"],["a mannequin wearing a multicolored dress"],["a close up of a dessert on a plate"],["a train traveling through a lush green countryside"],["an electronic device with a clock on top of it"],["a close up of a cell phone on a pole"],["a woman in a red lingerie posing for a picture"],["a view of a city from a bridge"],["a group of men standing in front of a table of food"],["a white bracelet with a blue flower on it"],["a single engine plane sitting on a runway"],["a woman standing in front of a wall"],["a staircase leading up to a second floor"],["a kitchen with a stove top oven sitting next to a window"],["a black and white photo of a man in a tuxedo"],["a living room filled with furniture and a kitchen in the background"],["a bed sitting in a bedroom next to a window"],["a large cargo ship in the water near a dock"],["a living room with a couch and a window"],["a girl's athletic shoe with pink laces"],["a bird's eye view of a beach and water"],["a kitchen with white cabinets and a b ...
